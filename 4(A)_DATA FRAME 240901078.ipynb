# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a -0.834034 -0.392979  0.105396
# b       NaN       NaN       NaN
# c -1.709032  0.550166  0.043959
# d -0.267027  0.453454  0.124234
# e       NaN       NaN       NaN
# f  0.745653  1.044480 -0.813467
#
#
# Dropped DataFrame
#          one       two     three
# a -0.834034 -0.392979  0.105396
# c -1.709032  0.550166  0.043959
# d -0.267027  0.453454  0.124234
# f  0.745653  1.044480 -0.813467

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.594119  1.188433  1.501747
# b       NaN       NaN       NaN
# c -1.162698  1.120254 -0.140319
#
#
# NaN replaced with '0':
#
#         one       two     three
# a -0.594119  1.188433  1.501747
# b  0.000000  0.000000  0.000000
# c -1.162698  1.120254 -0.140319

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  0.390069  0.589083  0.349160
# b       NaN       NaN       NaN
# c  1.139992 -1.731248  1.284625
# d -0.223537  1.273405  0.442024
# e       NaN       NaN       NaN
# f -0.781051  0.176564  1.110576
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.714592 -0.204954  0.646103
# b       NaN       NaN       NaN
# c  0.270378 -0.161654 -1.046343
# d  1.022399 -0.421906  0.784481
# e       NaN       NaN       NaN
# f -0.338869  0.871527  0.334483
#
# NaN - Filled with Background values:
#
#         one       two     three
# a  0.714592 -0.204954  0.646103
# b  0.270378 -0.161654 -1.046343
# c  0.270378 -0.161654 -1.046343
# d  1.022399 -0.421906  0.784481
# e -0.338869  0.871527  0.334483
# f -0.338869  0.871527  0.334483
